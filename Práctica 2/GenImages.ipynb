# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from keras.preprocessing.image import ImageDataGenerator
from skimage import io
datagen = ImageDataGenerator(        
            rotation_range=45,
            width_shift_range=0.2,  
            height_shift_range=0.2,    
            shear_range=0.2,        
            zoom_range=0.2)
import numpy as np
import os
from PIL import Image
image_directory = '/content/drive/My Drive/Universidad/Canarias/FSI/data/dataset/Pantalon/'
SIZE = 100
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
   if (image_name.split('.')[1] == 'jpg'):        
       image = io.imread(image_directory + image_name)        
       image = Image.fromarray(image, 'RGB')        
       image = image.resize((SIZE,SIZE)) 
       dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=32,
                          save_to_dir='/content/drive/My Drive/Universidad/Canarias/FSI/data/dataMejorado/Pantalon/',
                          save_prefix='pantalon',
                          save_format='jpg'):    
  i += 1    
  if i > 25:        
     break

# %%
image_directory = '/content/drive/My Drive/Universidad/Canarias/FSI/data/dataset/Camisas/'
SIZE = 100
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
   if (image_name.split('.')[1] == 'jpg'):        
       image = io.imread(image_directory + image_name)        
       image = Image.fromarray(image, 'RGB')        
       image = image.resize((SIZE,SIZE)) 
       dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=32,
                          save_to_dir='/content/drive/My Drive/Universidad/Canarias/FSI/data/dataMejorado/Camisas/',
                          save_prefix='camisa',
                          save_format='jpg'):    
  i += 1    
  if i > 25:        
     break

# %%
image_directory = '/content/drive/My Drive/Universidad/Canarias/FSI/data/dataset/Zapatos/'
SIZE = 100
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
   if (image_name.split('.')[1] == 'jpg'):        
       image = io.imread(image_directory + image_name)        
       image = Image.fromarray(image, 'RGB')        
       image = image.resize((SIZE,SIZE)) 
       dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=32,
                          save_to_dir='/content/drive/My Drive/Universidad/Canarias/FSI/data/dataMejorado/Zapatos/',
                          save_prefix='zapato',
                          save_format='jpg'):    
  i += 1    
  if i > 25:        
     break

# %%
image_directory = '/content/drive/My Drive/Universidad/Canarias/FSI/data/dataset/Faldas/'
SIZE = 100
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
   if (image_name.split('.')[1] == 'jpg'):        
       image = io.imread(image_directory + image_name)        
       image = Image.fromarray(image, 'RGB')        
       image = image.resize((SIZE,SIZE)) 
       dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=32,
                          save_to_dir='/content/drive/My Drive/Universidad/Canarias/FSI/data/dataMejorado/Faldas/',
                          save_prefix='falda',
                          save_format='jpg'):    
  i += 1    
  if i > 25:        
     break

# %%
image_directory = '/content/drive/My Drive/Universidad/Canarias/FSI/data/dataset/Camisetas/'
SIZE = 100
dataset = []
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):    
   if (image_name.split('.')[1] == 'jpg'):        
       image = io.imread(image_directory + image_name)        
       image = Image.fromarray(image, 'RGB')        
       image = image.resize((SIZE,SIZE)) 
       dataset.append(np.array(image))
x = np.array(dataset)
i = 0
for batch in datagen.flow(x, batch_size=32,
                          save_to_dir='/content/drive/My Drive/Universidad/Canarias/FSI/data/dataMejorado/Camisetas/',
                          save_prefix='camiseta',
                          save_format='jpg'):    
  i += 1    
  if i > 25:        
     break
